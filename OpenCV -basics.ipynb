# %%
# OpenCV supports a lot of algorithms related to Computer Vision and Machine Learning.
import numpy as np
import cv2
print(cv2.__version__)
# Out:
# 3.1.0

# %%
import numpy as np
import cv2

# Load an color image in grayscale
img = cv2.imread('kavya.jpg',0)

# %%
#How the picture is stored
img
# Out:
# array([[213, 214, 214, ..., 185, 186, 187],
#        [213, 214, 214, ..., 185, 186, 186],
#        [214, 214, 214, ..., 186, 186, 186],
#        ...,
#        [217, 210, 205, ..., 178, 179, 179],
#        [222, 214, 206, ..., 178, 178, 178],
#        [226, 217, 208, ..., 178, 178, 178]], dtype=uint8)

# %%
#To display the picture
cv2.imshow('image',img)

# %%
#Save the image in png format
cv2.imwrite('kavyagray.png',img)
# Out:
# True

# %%
#reading an image using Matplotlib

import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('kavya.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
  # to hide tick values on X and Y axis
plt.show()

# %%
#image thresholding
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)

titles = ['Original Image','BINARY','TRUNC','TOZERO']
images = [img, thresh1, thresh2, thresh3 ]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
#image transformation
img = cv2.imread('p1.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Output'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
#image smoothing
img = cv2.imread('p1.jpg')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
